# %%
import numpy as np
import pandas as pd
from sklearn.linear_model import LinearRegression

# %%
data = pd.read_csv('Predicting-House-Prices-In-Bengaluru-Train-Data.csv',nrows=50)
data.shape
# Out:
# (50, 9)

# %%
data.drop_duplicates(inplace = True)

# %%
data.shape
# Out:
# (50, 9)

# %%
data.isnull().sum()
# Out:
# area_type        0
# availability     0
# location         0
# size             0
# society         18
# total_sqft       0
# bath             0
# balcony          6
# price            0
# dtype: int64

# %%
data.describe()
# Out:
#             bath    balcony       price
# count  50.000000  44.000000   50.000000
# mean    2.700000   1.500000  105.571200
# std     1.446318   0.849076  110.724755
# min     1.000000   0.000000   15.000000
# 25%     2.000000   1.000000   41.250000
# 50%     2.000000   1.500000   61.000000
# 75%     3.000000   2.000000  122.750000
# max     9.000000   3.000000  600.000000

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 50 entries, 0 to 49
# Data columns (total 9 columns):
# area_type       50 non-null object
# availability    50 non-null object
# location        50 non-null object
# size            50 non-null object
# society         32 non-null object
# total_sqft      50 non-null object
# bath            50 non-null int64
# balcony         44 non-null float64
# price           50 non-null float64
# dtypes: float64(2), int64(1), object(6)
# memory usage: 3.9+ KB

# %%
data.size.sort_values(ascending = False)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-46-fd9d9c6a5790> in <module>()
# ----> 1 data.size.sort_values(ascending = False)
#
# AttributeError: 'numpy.int32' object has no attribute 'sort_values'

# %%
data.rename(columns={'size':'Roomsize'}, inplace = True)
data
# Out:
#                area_type   availability                  location   Roomsize  \
# 0   Super built-up  Area         19-Dec  Electronic City Phase II      2 BHK
# 1             Plot  Area  Ready To Move          Chikka Tirupathi  4 Bedroom
# 2         Built-up  Area  Ready To Move               Uttarahalli      3 BHK
# 3   Super built-up  Area  Ready To Move        Lingadheeranahalli      3 BHK
# 4   Super built-up  Area  Ready To Move                  Kothanur      2 BHK
# 5   Super built-up  Area  Ready To Move                Whitefield      2 BHK
# 6   Super built-up  Area         18-May          Old Airport Road      4 BHK
# 7   Super built-up  Area  Ready To Move              Rajaji Nagar      4 BHK
# 8   Super built-up  Area  Ready To Move              Marathahalli      3 BHK
# 9             Plot  Area  Ready To Move              Gandhi Bazar  6 Bedroom
# 10  Super built-up  Area         18-Feb                Whitefield      3 BHK
# ...

# %%
data.replace(r'^\s*$', np.nan, regex=True)
# Out:
#                area_type   availability                  location   Roomsize  \
# 0   Super built-up  Area         19-Dec  Electronic City Phase II      2 BHK
# 1             Plot  Area  Ready To Move          Chikka Tirupathi  4 Bedroom
# 2         Built-up  Area  Ready To Move               Uttarahalli      3 BHK
# 3   Super built-up  Area  Ready To Move        Lingadheeranahalli      3 BHK
# 4   Super built-up  Area  Ready To Move                  Kothanur      2 BHK
# 5   Super built-up  Area  Ready To Move                Whitefield      2 BHK
# 6   Super built-up  Area         18-May          Old Airport Road      4 BHK
# 7   Super built-up  Area  Ready To Move              Rajaji Nagar      4 BHK
# 8   Super built-up  Area  Ready To Move              Marathahalli      3 BHK
# 9             Plot  Area  Ready To Move              Gandhi Bazar  6 Bedroom
# 10  Super built-up  Area         18-Feb                Whitefield      3 BHK
# ...

# %%
data.Roomsize.str.replace(' Bedroom',' BHK')
# Out:
# 0     2 BHK
# 1     4 BHK
# 2     3 BHK
# 3     3 BHK
# 4     2 BHK
# 5     2 BHK
# 6     4 BHK
# 7     4 BHK
# 8     3 BHK
# 9     6 BHK
# 10    3 BHK
# 11    4 BHK
# 12    2 BHK
# 13    2 BHK
# 14    3 BHK
# 15    2 BHK
# 16    3 BHK
# 17    3 BHK
# 18    3 BHK
# 19    2 BHK
# 20    1 BHK
# 21    3 BHK
# 22    4 BHK
# 23    3 BHK
# 24     1 RK
# 25    3 BHK
# 26    2 BHK
# 27    3 BHK
# 28    2 BHK
# 29    3 BHK
# 30    4 BHK
# 31    3 BHK
# 32    3 BHK
# 33    3 BHK
# 34    3 BHK
# 35    2 BHK
# 36    2 BHK
# 37    3 BHK
# 38    3 BHK
# 39    2 BHK
# 40    2 BHK
# 41    3 BHK
# 42    1 BHK
# 43    1 BHK
# 44    2 BHK
# 45    8 BHK
# 46    2 BHK
# 47    2 BHK
# 48    2 BHK
# 49    2 BHK
# Name: Roomsize, dtype: object

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 50 entries, 0 to 49
# Data columns (total 9 columns):
# area_type       50 non-null object
# availability    50 non-null object
# location        50 non-null object
# Roomsize        50 non-null object
# society         32 non-null object
# total_sqft      50 non-null object
# bath            50 non-null int64
# balcony         44 non-null float64
# price           50 non-null float64
# dtypes: float64(2), int64(1), object(6)
# memory usage: 6.4+ KB

# %%
data.Roomsize.fillna(method = "ffill", inplace = True)
data
# Out:
#                area_type   availability                  location   Roomsize  \
# 0   Super built-up  Area         19-Dec  Electronic City Phase II      2 BHK
# 1             Plot  Area  Ready To Move          Chikka Tirupathi  4 Bedroom
# 2         Built-up  Area  Ready To Move               Uttarahalli      3 BHK
# 3   Super built-up  Area  Ready To Move        Lingadheeranahalli      3 BHK
# 4   Super built-up  Area  Ready To Move                  Kothanur      2 BHK
# 5   Super built-up  Area  Ready To Move                Whitefield      2 BHK
# 6   Super built-up  Area         18-May          Old Airport Road      4 BHK
# 7   Super built-up  Area  Ready To Move              Rajaji Nagar      4 BHK
# 8   Super built-up  Area  Ready To Move              Marathahalli      3 BHK
# 9             Plot  Area  Ready To Move              Gandhi Bazar  6 Bedroom
# 10  Super built-up  Area         18-Feb                Whitefield      3 BHK
# ...

# %%
data.isnull().sum()
# Out:
# area_type        0
# availability     0
# location         0
# Roomsize         0
# society         18
# total_sqft       0
# bath             0
# balcony          6
# price            0
# dtype: int64

# %%
data[data.location.isnull()]
# Out:
# Empty DataFrame
# Columns: [area_type, availability, location, Roomsize, society, total_sqft, bath, balcony, price]
# Index: []

# %%
data.location.fillna(method = "ffill", inplace = True)

# %%
data.isnull().sum()
# Out:
# area_type        0
# availability     0
# location         0
# Roomsize         0
# society         18
# total_sqft       0
# bath             0
# balcony          6
# price            0
# dtype: int64

# %%
data.area_type = data.area_type.astype('str')
data.area_type.dtype
# Out:
# dtype('O')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 50 entries, 0 to 49
# Data columns (total 9 columns):
# area_type       50 non-null object
# availability    50 non-null object
# location        50 non-null object
# Roomsize        50 non-null object
# society         32 non-null object
# total_sqft      50 non-null object
# bath            50 non-null int64
# balcony         44 non-null float64
# price           50 non-null float64
# dtypes: float64(2), int64(1), object(6)
# memory usage: 6.4+ KB

# %%
data.society.fillna(method = "ffill", inplace = True)
data.bath.fillna(method = "ffill", inplace = True)
data.balcony.fillna(method = "ffill", inplace = True)

# %%
data.describe()
# Out:
#             bath    balcony       price
# count  50.000000  50.000000   50.000000
# mean    2.700000   1.520000  105.571200
# std     1.446318   0.838852  110.724755
# min     1.000000   0.000000   15.000000
# 25%     2.000000   1.000000   41.250000
# 50%     2.000000   1.500000   61.000000
# 75%     3.000000   2.000000  122.750000
# max     9.000000   3.000000  600.000000

# %%
data.isnull().sum()
# Out:
# area_type       0
# availability    0
# location        0
# Roomsize        0
# society         0
# total_sqft      0
# bath            0
# balcony         0
# price           0
# dtype: int64

# %%
'''data['area_type'] = data['area_type'].astype(str)
data['location'] = data['location'].astype(str)
data['total_sqft'] = data['total_sqft'].astype(str)
data['price'] = data['price'].astype(str) '''
print (data.info())
x_train = data.loc[:,["area_type","location","total_sqft"]]
y_train = data.price
print (x_train.shape)
print (y_train.shape)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 50 entries, 0 to 49
# Data columns (total 9 columns):
# area_type       50 non-null object
# availability    50 non-null object
# location        50 non-null object
# Roomsize        50 non-null object
# society         50 non-null object
# total_sqft      50 non-null object
# bath            50 non-null int64
# balcony         50 non-null float64
# price           50 non-null float64
# dtypes: float64(2), int64(1), object(6)
# memory usage: 6.4+ KB
# None
# (50, 3)
# (50,)

# %%
testdata = pd.read_csv('Predicting-House-Prices-In-Bengaluru-Test-Data.csv')
testdata.isnull().sum()
testdata.drop_duplicates(inplace = True)
testdata.shape
testdata.isnull().sum()
# Out:
# area_type          0
# availability       0
# location           0
# size               2
# society          617
# total_sqft         0
# bath               5
# balcony           67
# price           1447
# dtype: int64

# %%
x_test = testdata.loc[:,["total_sqft"]]
y_test = testdata.price

# %%
model = LinearRegression()
model.fit(x_train,y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-66-4f30f9ee332f> in <module>()
#       1 model = LinearRegression()
# ----> 2 model.fit(x_train,y_train)
#
# ~\Anaconda3\lib\site-packages\sklearn\linear_model\base.py in fit(self, X, y, sample_weight)
#     480         n_jobs_ = self.n_jobs
#     481         X, y = check_X_y(X, y, accept_sparse=['csr', 'csc', 'coo'],
# --> 482                          y_numeric=True, multi_output=True)
#     483
#     484         if sample_weight is not None and np.atleast_1d(sample_weight).ndim > 1:
#
# ~\Anaconda3\lib\site-packages\sklearn\utils\validation.py in check_X_y(X, y, accept_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, warn_on_dtype, estimator)
#     571     X = check_array(X, accept_sparse, dtype, order, copy, force_all_finite,
# ...

# %%
x.train.iloc[1131]
# Out:
# area_type     Super built-up  Area
# location                    Hennur
# total_sqft                    1255
# Name: 1133, dtype: object
